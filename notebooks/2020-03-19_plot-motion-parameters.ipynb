# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline
from glob import glob

# %%
fns = sorted(glob('/home/vassiki/budapest_data/outputs/fmriprep/sub-sid000007/func/*.tsv'))

# %%
dfs = [pd.read_csv(f, sep='\t') for f in fns]

# %%
keep_columns = [
    'framewise_displacement',
    'rot_x', 'rot_y', 'rot_z',
    'trans_x', 'trans_y', 'trans_z'
]

# %%
dfs = [df[keep_columns] for df in dfs]

# %%
fig, ax = plt.subplots(5, 1, figsize=(12, 8), sharey=True, sharex=True)
for axx, df in zip(ax.flat, dfs):
    d = df['framewise_displacement']
    axx.plot(d)
    axx.axhline(np.nanmean(d), color='lightgray', linestyle='dashed')

# %%
fig, ax = plt.subplots(5, 1, figsize=(12, 8), sharey=True, sharex=True)
for axx, df in zip(ax, dfs):
    d = df[[f'trans_{w}' for w in 'xyz']]
    axx.plot(d)

# %%
fig, ax = plt.subplots(5, 1, figsize=(12, 8), sharey=True, sharex=True)
for axx, df in zip(ax, dfs):
    d = df[[f'rot_{w}' for w in 'xyz']]
    axx.plot(d)

# %%
fig, ax = plt.subplots(5, 1, figsize=(12, 8), sharey=True, sharex=True)
for axx, df in zip(ax.flat, dfs):
    d = df['framewise_displacement']
    axx.hist(d, bins=100);
# Out:
# /home/contematto/miniconda3/envs/budapest/lib/python3.8/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/contematto/miniconda3/envs/budapest/lib/python3.8/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
[np.median]

# %%
fig, ax = plt.subplots(5, 1, figsize=(12, 8), sharey=True, sharex=True)
for axx, df in zip(ax.flat, dfs):
    axx.plot(df['framewise_displacement'])

# %%
fig, ax = plt.subplots(5, 1, figsize=(12, 8), sharey=True, sharex=True)
for axx, df in zip(ax.flat, dfs):
    axx.plot(df['framewise_displacement'])

# %%
fig, ax = plt.subplots(5, 1, figsize=(12, 8), sharey=True, sharex=True)
for axx, df in zip(ax.flat, dfs):
    axx.plot(df['framewise_displacement'])
